# %%
import pandas as pd

# %%
df_soft = pd.read_csv("evaluation_results_soft.csv").sort_values(["ICMSoft", "ICMSoftNorm"], ascending=False)
df_hard = pd.read_csv("evaluation_results_hard.csv").sort_values(["ICM", "ICMNorm"], ascending=False)

# %%
task_2_1_soft = df_soft[df_soft["task"] == 2.1]
task_2_1_hard = df_hard[df_hard["task"] == 2.1]
task_2_2_soft = df_soft[df_soft["task"] == 2.2]
task_2_2_hard = df_hard[df_hard["task"] == 2.2]
task_2_3_soft = df_soft[df_soft["task"] == 2.3]
task_2_3_hard = df_hard[df_hard["task"] == 2.3]

# %% [markdown]
# # Summary

# %%
# Show 1st model for each task
print("Soft-Soft Setup:")
display(task_2_1_soft.head(1))
display(task_2_2_soft.head(1))
display(task_2_3_soft.head(1))
# Out:
# Soft-Soft Setup:
#    task          model               file  mode   ICMSoft  ICMSoftNorm  \
# 0   2.1  gemini_1block  task2_1_soft.json  soft  1.335221     0.709888
#
#    CrossEntropy
# 0      0.827839
#     task                      model               file  mode   ICMSoft  \
# 18   2.2  gemini_2block_4exp_gating  task2_2_soft.json  soft  0.992692
#
#     ICMSoftNorm  CrossEntropy
# 18     0.603843      1.214209
#     task                              model               file  mode  \
# 35   2.3  gemini_4block_4exp_gating_seed_42  task2_3_soft.json  soft
#
#      ICMSoft  ICMSoftNorm  CrossEntropy
# 35 -1.035991     0.445904           NaN

# %%
# Show 1st model for each task
print("Hard-Hard Setup:")
display(task_2_1_hard.head(1))
display(task_2_2_hard.head(1))
display(task_2_3_hard.head(1))
# Out:
# Hard-Hard Setup:
#    task          model               file  mode       ICM   ICMNorm  FMeasure
# 0   2.1  gemini_1block  task2_1_hard.json  hard  0.722603  0.870888  0.838881
#     task          model               file  mode       ICM   ICMNorm  FMeasure
# 18   2.2  gemini_1block  task2_2_hard.json  hard  0.829592  0.786902  0.703932
#     task          model               file  mode       ICM  ICMNorm  FMeasure
# 35   2.3  gemini_1block  task2_3_hard.json  hard  0.713889  0.64552  0.606022

# %% [markdown]
# ### 2.1 - Soft

# %%
task_2_1_soft
# Out:
#     task                              model  \
# 0    2.1                      gemini_1block
# 1    2.1          gemini_2block_4exp_gating
# 2    2.1               gemini_1block_gating
# 3    2.1               gemini_2block_gating
# 4    2.1  gemini_4block_4exp_gating_seed_42
# 5    2.1               gemini_4block_gating
# 6    2.1  gemini_1block_4exp_gating_seed_42
# 7    2.1                      gemini_4block
# 8    2.1       siglip_1block_gating_seed_42
# 9    2.1  gemini_1block_1exp_gating_seed_42
# 10   2.1                          gemini_kl
# 11   2.1                   gemini_cascading
# 12   2.1                  gemini_bce_swiglu
# 13   2.1                gemini_bce_swiglu_2
# 14   2.1                     gemini_bce_old
# 15   2.1                             siglip
# 16   2.1                  baseline_majority
# 17   2.1                  baseline_minority
#
#                                                  file  mode   ICMSoft  \
# ...

# %% [markdown]
# ### 2.2 - Soft

# %%
task_2_2_soft
# Out:
#     task                              model  \
# 18   2.2          gemini_2block_4exp_gating
# 19   2.2                      gemini_4block
# 20   2.2  gemini_4block_4exp_gating_seed_42
# 21   2.2                      gemini_1block
# 22   2.2               gemini_4block_gating
# 23   2.2               gemini_2block_gating
# 24   2.2               gemini_1block_gating
# 25   2.2  gemini_1block_4exp_gating_seed_42
# 26   2.2  gemini_1block_1exp_gating_seed_42
# 27   2.2       siglip_1block_gating_seed_42
# 28   2.2                  gemini_bce_swiglu
# 29   2.2                gemini_bce_swiglu_2
# 30   2.2                   gemini_cascading
# 31   2.2                     gemini_bce_old
# 32   2.2                          gemini_kl
# 33   2.2                  baseline_majority
# 34   2.2                  baseline_minority
#
#                                                  file  mode    ICMSoft  \
# 18                                  task2_2_soft.json  soft   0.992692
# ...

# %% [markdown]
# ### 2.3 - Soft

# %%
task_2_3_soft
# Out:
#     task                              model  \
# 35   2.3  gemini_4block_4exp_gating_seed_42
# 36   2.3                      gemini_4block
# 37   2.3          gemini_2block_4exp_gating
# 38   2.3               gemini_4block_gating
# 39   2.3               gemini_2block_gating
# 40   2.3               gemini_1block_gating
# 41   2.3                      gemini_1block
# 42   2.3       siglip_1block_gating_seed_42
# 43   2.3                          gemini_kl
# 44   2.3                  gemini_bce_swiglu
# 45   2.3                   gemini_cascading
# 46   2.3                gemini_bce_swiglu_2
# 47   2.3                     gemini_bce_old
# 48   2.3  gemini_1block_1exp_gating_seed_42
# 49   2.3  gemini_1block_4exp_gating_seed_42
# 50   2.3                  baseline_majority
# 51   2.3                  baseline_minority
#
#                                                  file  mode    ICMSoft  \
# 35                                  task2_3_soft.json  soft  -1.035991
# ...

# %% [markdown]
# ### 2.1 - Hard

# %%
task_2_1_hard
# Out:
#     task                              model  \
# 0    2.1                      gemini_1block
# 1    2.1          gemini_2block_4exp_gating
# 2    2.1               gemini_1block_gating
# 3    2.1  gemini_1block_1exp_gating_seed_42
# 4    2.1               gemini_2block_gating
# 5    2.1  gemini_4block_4exp_gating_seed_42
# 6    2.1       siglip_1block_gating_seed_42
# 7    2.1                      gemini_4block
# 8    2.1  gemini_1block_4exp_gating_seed_42
# 9    2.1               gemini_4block_gating
# 10   2.1                          gemini_kl
# 11   2.1                   gemini_cascading
# 12   2.1                  gemini_bce_swiglu
# 13   2.1                     gemini_bce_old
# 14   2.1                gemini_bce_swiglu_2
# 15   2.1                  baseline_majority
# 16   2.1                             siglip
# 17   2.1                  baseline_minority
#
#                                                  file  mode       ICM  \
# ...

# %% [markdown]
# ### 2.2 - Hard

# %%
task_2_2_hard
# Out:
#     task                              model  \
# 18   2.2                      gemini_1block
# 19   2.2          gemini_2block_4exp_gating
# 20   2.2       siglip_1block_gating_seed_42
# 21   2.2  gemini_4block_4exp_gating_seed_42
# 22   2.2  gemini_1block_4exp_gating_seed_42
# 23   2.2                      gemini_4block
# 24   2.2  gemini_1block_1exp_gating_seed_42
# 25   2.2               gemini_1block_gating
# 26   2.2               gemini_2block_gating
# 27   2.2               gemini_4block_gating
# 28   2.2                          gemini_kl
# 29   2.2                   gemini_cascading
# 30   2.2                     gemini_bce_old
# 31   2.2                  gemini_bce_swiglu
# 32   2.2                gemini_bce_swiglu_2
# 33   2.2                  baseline_majority
# 34   2.2                  baseline_minority
#
#                                                  file  mode       ICM  \
# 18                                  task2_2_hard.json  hard  0.829592
# ...

# %% [markdown]
# ### 2.3 - Hard

# %%
task_2_3_hard
# Out:
#     task                              model  \
# 35   2.3                      gemini_1block
# 36   2.3  gemini_4block_4exp_gating_seed_42
# 37   2.3  gemini_1block_1exp_gating_seed_42
# 38   2.3          gemini_2block_4exp_gating
# 39   2.3  gemini_1block_4exp_gating_seed_42
# 40   2.3                      gemini_4block
# 41   2.3               gemini_4block_gating
# 42   2.3               gemini_1block_gating
# 43   2.3               gemini_2block_gating
# 44   2.3       siglip_1block_gating_seed_42
# 45   2.3                     gemini_bce_old
# 46   2.3                  baseline_majority
# 47   2.3                  baseline_minority
#
#                                                  file  mode       ICM  \
# 35                                  task2_3_hard.json  hard  0.713889
# 36                                  task2_3_hard.json  hard  0.678118
# 37                                  task2_3_hard.json  hard  0.667291
# ...
