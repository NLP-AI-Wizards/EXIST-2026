# %%
import pandas as pd

# %%
df_soft = pd.read_csv("evaluation_results_soft.csv")
df_hard = pd.read_csv("evaluation_results_hard.csv")

# %%
# Show the ICMSoftNorm for each task, sorted by the ICMSoftNorm score
df_soft.sort_values(by="ICMSoftNorm", ascending=False)
# Out:
#                   model                                  file  task  mode  \
# 0         gemini_1block                     task2_1_soft.json   2.1  soft
# 15            gemini_kl                     task2_1_soft.json   2.1  soft
# 12     gemini_cascading                     task2_1_soft.json   2.1  soft
# 6     gemini_bce_swiglu                     task2_1_soft.json   2.1  soft
# 9   gemini_bce_swiglu_2                     task2_1_soft.json   2.1  soft
# 3        gemini_bce_old                     task2_1_soft.json   2.1  soft
# 18               siglip  siglip_12_04_14-25_task2_1_soft.json   2.1  soft
# 4        gemini_bce_old                     task2_2_soft.json   2.2  soft
# 10  gemini_bce_swiglu_2                     task2_2_soft.json   2.2  soft
# 7     gemini_bce_swiglu                     task2_2_soft.json   2.2  soft
# 13     gemini_cascading                     task2_2_soft.json   2.2  soft
# 5        gemini_bce_old                     task2_3_soft.json   2.3  soft
# ...

# %%
df_hard.sort_values(by="ICMNorm", ascending=False)
# Out:
#                   model                                  file  task  mode  \
# 0         gemini_1block                     task2_1_hard.json   2.1  hard
# 10            gemini_kl                     task2_1_hard.json   2.1  hard
# 8      gemini_cascading                     task2_1_hard.json   2.1  hard
# 4     gemini_bce_swiglu                     task2_1_hard.json   2.1  hard
# 2        gemini_bce_old                     task2_1_hard.json   2.1  hard
# 6   gemini_bce_swiglu_2                     task2_1_hard.json   2.1  hard
# 12               siglip  siglip_12_04_14-25_task2_1_hard.json   2.1  hard
# 1         gemini_1block                     task2_2_hard.json   2.2  hard
# 11            gemini_kl                     task2_2_hard.json   2.2  hard
# 9      gemini_cascading                     task2_2_hard.json   2.2  hard
# 5     gemini_bce_swiglu                     task2_2_hard.json   2.2  hard
# 3        gemini_bce_old                     task2_2_hard.json   2.2  hard
# ...
